# %%
# %matplotlib inline

# %%
from vizztf import ZTFSNViz

# %%
from opsimsummary import convertToSphericalCoordinates, convertToCelestialCoordinates, MilkyWayExtension

# %%
ztfsky = ZTFSNViz()

# %%
fig, ax, m = ztfsky.generate_image_bg(bg_color='b', mwcolor='w', fillmw=True, mw_lw=1,
                                      mw_alpha=1.0, mw_edgecolor='k' )
# Out:
# /usr/local/miniconda/lib/python2.7/site-packages/matplotlib/patches.py:107: UserWarning: Setting the 'color' property will overridethe edgecolor or facecolor properties.
#   warnings.warn("Setting the 'color' property will override"

# %%
x = []
y = []
ax.hist(x, color='b', label='EGF')
ax.hist(y, color='r', label='MW')
ax.legend(loc='upper right', bbox_to_anchor=(1,1))

# %%
fig

# %%
ax.legend(loc='best')
# Out:
# /usr/local/miniconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
fig

# %%
fig, ax, m = ztfsky.generate_image_bg(bg_color='w', mwcolor='k', fillmw=False, mw_lw=1,
                                      mw_alpha=1.0, mw_edgecolor='k' )

# %% [markdown]
# # Scratch

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(12,6))
m = Basemap(projection='moll', lon_0=0, lat_0=0, ax=ax)

# %%
_ = m.drawmeridians(np.arange(-180., 180, 60))
_ = m.drawparallels(np.arange(-90., 90., 60.))
_ = m.drawmapboundary(fill_color='b')

# %%
fig

# %%
x = []
y = []
ax.hist(x, color='b', label='EGF')
ax.hist(y, color='r', label='MW')
ax.legend(loc='upper right', bbox_to_anchor=(1,1))

# %%
fig
