# %%
# %matplotlib inline

# %%
from vizztf import ZTFSNViz

# %%
from opsimsummary import convertToSphericalCoordinates, convertToCelestialCoordinates, MilkyWayExtension

# %%
ztfsky = ZTFSNViz()

# %%
fig, ax, m = ztfsky.generate_image_bg(bg_color='w')

# %%
mwext = MilkyWayExtension(m)

# %%
p = mwext.mw_polygon

# %%
ax.add_patch(p)

# %%
fig
