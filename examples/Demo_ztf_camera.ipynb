# %%
# %matplotlib inline

# %%
from vizztf import ZTFSNViz

# %%
ztfsky = ZTFSNViz(showVisibleFields=True, 
                  data_dir='/Users/rbiswas/doc/projects/ZTF/data_year/')

# %%
from opsimsummary import AllSkyMap

# %%
asm = AllSkyMap()

# %%
fig, ax, m = ztfsky.generate_image_bg(mwcolor='y', mw_alpha=0.7)

# %%
ztfsky.generate_camera(30, 20, m, ax, default_color='k', band='i')

# %%
fig

# %%
ztfsky.generate_camera(0, 0, m, ax, default_color='k', band='r')

# %%
fig

# %%
ztfsky.generate_camera(178, 0, m, ax, default_color='k', band='g')

# %%
fig

# %%
ztfsky.generate_camera(182, 0, m, ax, default_color='k', band='r')

# %%
fig

# %%
ztfsky.generate_camera(-178, 30, m, ax, default_color='k', band='r')

# %%
fig

# %%
ztfsky.generate_camera(164, 30, m, ax, default_color='k', band='r')

# %%
fig

# %%
polyseg = ztfsky.generate_camera(180., 82, m, ax, default_color='k', band='r')

# %%
fig
